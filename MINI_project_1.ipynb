# %% [markdown]
# <a href="https://colab.research.google.com/github/adarshparjapati6-hash/CRYPTOCURRENCY_ML_PROJECT/blob/main/MINI_project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Practical 1: Student Performance Management System
#  Problem Statement
# - A school wants to automate the process of managing student records. Develop a Python program
# that stores student details and marks, calculates percentages, assigns grades, and displays the
# topper.

# %%
students = []

n = int(input("Enter number of students: "))

for i in range(n):
    name = input("Enter student name: ")

    marks1 = float(input("Enter marks in Subject 1: "))
    marks2 = float(input("Enter marks in Subject 2: "))
    marks3 = float(input("Enter marks in Subject 3: "))

    total = marks1 + marks2 + marks3
    percentage = total / 3

    if percentage >= 90:
        grade = "A+"
    elif percentage >= 75:
        grade = "A"
    elif percentage >= 60:
        grade = "B"
    elif percentage >= 45:
        grade = "C"
    else:
        grade = "F"

    students.append({
        "name": name,
        "percentage": percentage,
        "grade": grade
    })

print("\nStudent Records")
for student in students:
    print("Name:", student["name"])
    print("Percentage:", round(student["percentage"], 2))
    print("Grade:", student["grade"])
    print()

topper = students[0]

for student in students:
    if student["percentage"] > topper["percentage"]:
        topper = student

print("Topper Details")
print("Name:", topper["name"])
print("Percentage:", round(topper["percentage"], 2))
print("Grade:", topper["grade"])
# Out:
# Enter number of students: 2
# Enter student name: adarsh
# Enter marks in Subject 1: 32
# Enter marks in Subject 2: 54
# Enter marks in Subject 3: 78
# Enter student name: karan
# Enter marks in Subject 1: 43
# Enter marks in Subject 2: 56
# Enter marks in Subject 3: 24
#
# Student Records
# Name: adarsh
# Percentage: 54.67
# Grade: C
#
# Name: karan
# Percentage: 41.0
# Grade: F
#
# Topper Details
# Name: adarsh
# Percentage: 54.67
# Grade: C
